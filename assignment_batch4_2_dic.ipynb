# %% [markdown]
# # Basic Dictionay Operations

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs (name, age, city).

# %%
dictn = {"name":"Disha" , "age": 24 , "city":"Nagpur"}
print(dictn)
# Out:
# {'name': 'Disha', 'age': 24, 'city': 'Nagpur'}

# %% [markdown]
# 2. Create a dictionary and print the value of a specific key.

# %%
dictn = {"name":"Disha" , "age": 24 , "city":"Nagpur"}
print(dictn["name"])
# Out:
# Disha

# %% [markdown]
# 3. Make a dictionary and add a new key-value pair to it.

# %%
dictn = {"name":"Disha" , "age": 24 , "city":"Nagpur"}
dictn["colore"] = "Fair"
print(dictn)
# Out:
# {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}

# %% [markdown]
# 4. Create a dictionary and change the value of an existing key.

# %%
dictn = {"name":"Disha" , "age": 24 , "city":"Nagpur"}
dictn["age"] = 25
print(dictn)
# Out:
# {'name': 'Disha', 'age': 25, 'city': 'Nagpur'}

# %% [markdown]
# 5. Create a dictionary and remove one key using pop().

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
student.pop("colore")
print(student)
# Out:
# {'name': 'Disha', 'age': 24, 'city': 'Nagpur'}

# %% [markdown]
# 6. Create a dictionary and remove the last inserted item using popitem().

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
student.popitem()
print(student)
# Out:
# {'name': 'Disha', 'age': 24, 'city': 'Nagpur'}

# %% [markdown]
# 7. Create a dictionary and print all the keys.

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'city', 'colore'])

# %% [markdown]
# 8. Create a dictionary and print all the values.

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
print(student.values())
# Out:
# dict_values(['Disha', 24, 'Nagpur', 'Fair'])

# %% [markdown]
# 9. Create a dictionary and print all the key-value items.

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
print(student.items())
# Out:
# dict_items([('name', 'Disha'), ('age', 24), ('city', 'Nagpur'), ('colore', 'Fair')])

# %% [markdown]
# 10. Make a dictionary and check the number of items using len().

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
print(len(student))
# Out:
# 4

# %% [markdown]
# 11. Create a dictionary and check if a certain key exists (using "key" in dict).

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
print("city" in student)
# Out:
# True

# %% [markdown]
# 12. Create an empty dictionary and add two key-value pairs one by one.

# %%
dcs = {}
dcs["mark1","mark2"] = 45,65
print(dcs)
# Out:
# {('mark1', 'mark2'): (45, 65)}

# %% [markdown]
# 13. Create a dictionary and update one key’s value using update().

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
student.update({"name":"Dishani"})
student
# Out:
# {'name': 'Dishani', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}

# %% [markdown]
# 14. Create two dictionaries and combine them using update().

# %%
student = {"name": "Amit","age": 20,"city": "Pune"}
course = {"subject": "Python","duration": "3 months","fee": 60000}
student.update(course)
print(student)
# Out:
# {'name': 'Amit', 'age': 20, 'city': 'Pune', 'subject': 'Python', 'duration': '3 months', 'fee': 60000}

# %% [markdown]
# 15. Make a dictionary and get the value of a key using get().

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
print(student.get("name"))
# Out:
# Disha

# %% [markdown]
# 16. Create a dictionary and print its type using type().

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
print(type(student))
# Out:
# <class 'dict'>

# %% [markdown]
# 17. Create a dictionary and replace one value with a new one.

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
student["age"]=21
print(student)
# Out:
# {'name': 'Disha', 'age': 21, 'city': 'Nagpur', 'colore': 'Fair'}

# %% [markdown]
# 18. Create a dictionary and clear all items using clear().

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
student.clear()
student
# Out:
# {}

# %% [markdown]
# 19. Create a dictionary with numbers as keys and names as values. Print the dictionary.

# %%
roll_num = {1:"ram",2:"sham",3:"mohan",4:"mahi"}
print(roll_num)
# Out:
# {1: 'ram', 2: 'sham', 3: 'mohan', 4: 'mahi'}

# %% [markdown]
# 20. Create a dictionary and copy it into a new dictionary using copy().

# %%
student = {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
student1 = student.copy()
student1
# Out:
# {'name': 'Disha', 'age': 24, 'city': 'Nagpur', 'colore': 'Fair'}
